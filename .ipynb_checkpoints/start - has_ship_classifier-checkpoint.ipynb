# %% [markdown]
# ### download data

# %%
#!kaggle competitions download -c airbus-ship-detection

# %% [markdown]
# ### begin

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

import sys
import shutil
import os
from pathlib import Path
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split

# %%
sys.path.append("../fastai/")
from fastai.conv_learner import *

# %%
path = Path("../DATA/airbus-ship/")
files = list(path.iterdir())

# %%
files
# Out:
# [PosixPath('../DATA/airbus-ship/segmentations'),
#  PosixPath('../DATA/airbus-ship/classification'),
#  PosixPath('../DATA/airbus-ship/test_ship_segmentations.csv'),
#  PosixPath('../DATA/airbus-ship/test_all'),
#  PosixPath('../DATA/airbus-ship/sample_submission.csv'),
#  PosixPath('../DATA/airbus-ship/models'),
#  PosixPath('../DATA/airbus-ship/train_all'),
#  PosixPath('../DATA/airbus-ship/train_ship_segmentations.csv')]

# %%
plt.imshow(open_image(list((path/'train_all').iterdir())[10]))

# %% [markdown]
# ### Get stats about images
#
# **IMPORTANT NOTE** : DUE TO DATA LEAKAGE TEST SET IS NOW PART OF TRAIN AND NEW TEST SET WILL ARRIVE. https://www.kaggle.com/c/airbus-ship-detection/discussion/64702

# %%
train_files = list((path/'train_all').iterdir())
test_files = list((path/'test_all').iterdir())

# %%
train_segmentations = pd.read_csv(path/'train_ship_segmentations.csv')
test_segmentations = pd.read_csv(path/'test_ship_segmentations.csv')

# %%
print(f"number of image files: {len(train_files) + len(test_files)}")
# Out:
# number of image files: 192570

# %%
# there may be more than one instances per image
print(f"number of annotations/ships: {train_segmentations.shape[0] +  test_segmentations.shape[0]}")
# Out:
# number of annotations/ships: 231723

# %%
fig, axes = plt.subplots(figsize=(10,10))
axes.imshow(open_image(str(path/"train_all/00021ddc3.jpg")))

# %%
# ratio of images without ships
trn_no_ship = (train_segmentations.has_ship==0).sum() / train_segmentations.ImageId.nunique()
print(f"train images without ship: {np.round(trn_no_ship, 4)}")
# Out:
# train images without ship: 0.7207

# %%
# ratio of images without ships
test_no_ship = (test_segmentations.has_ship==0).sum() / test_segmentations.ImageId.nunique()
print(f"test images without ship: {np.round(test_no_ship, 4)}")
# Out:
# test images without ship: 0.8476

# %%
train_segmentations.head()
# Out:
#          ImageId                                      EncodedPixels  has_ship
# 0  00003e153.jpg                                                NaN         0
# 1  000155de5.jpg  264661 17 265429 33 266197 33 266965 33 267733...         1
# 2  00021ddc3.jpg  101361 1 102128 3 102896 4 103663 6 104430 9 1...         1
# 3  00021ddc3.jpg  95225 2 95992 5 96760 7 97527 9 98294 9 99062 ...         1
# 4  00021ddc3.jpg  74444 4 75212 4 75980 4 76748 4 77517 3 78285 ...         1

# %% [markdown]
# ### Visualizing data

# %%
from rle import rle_decode, rle_encode

# %%
train_all_labels = pd.read_csv(path/"classification/train_all_lbs.csv")
test_all_labels = pd.read_csv(path/"classification/test_all_lbs.csv")

# %%
print(f"# of train images: {len(train_files)}, # of train labels: {len(train_all_labels)}")
print(f"# of train images: {len(test_files)}, # of train labels: {len(test_all_labels)}")
# Out:
# # of train images: 173314, # of train labels: 173300
# # of train images: 19256, # of train labels: 19256

# %% [markdown]
# ### model 1 -  has ship classifier
#
# - set CropType.NO - not to remove ship during center cropping

# %%
_, val_idx = train_test_split(train_all_labels, test_size=0.1, stratify=train_all_labels.has_ship, random_state=42)
val_idx = (val_idx.index).tolist()

# %%
arch = resnet18
sz = 224

# %%
tfms = tfms_from_model(arch, sz, aug_tfms=transforms_top_down, max_zoom=1.1)

# %%
# cv_idxs automatically creates validation set
data = ImageClassifierData.from_csv(path, folder='train_all', bs=128, val_idxs=val_idx,
                                    csv_fname=path/'classification/train_all_lbs.csv',
                                    tfms=tfms, test_name="test_all")

# %%
print(f"n train: {len(data.trn_ds)}, n val: {len(data.val_ds)}")
# Out:
# n train: 155970, n val: 17330

# %%
# number of images without ships : majority prediction
baseline = 1 - np.mean(data.val_ds.y); print(f"baseline acc: {np.round(baseline,4)}")
# Out:
# baseline acc: 0.779

# %%
learn = ConvLearner.pretrained(arch, data, precompute=False)

# %%
learn.lr_find()

# %%
learn.sched.plot()

# %%
learn.fit(1e-2, 10, cycle_len=1)
# Out:
# ...
# epoch      trn_loss   val_loss   accuracy
#     0      0.215418   0.175501   0.936815
#     1      0.193823   0.164612   0.939527
#     2      0.196095   0.16301    0.940162
#     3      0.193763   0.158723   0.941662
#     4      0.18775    0.157721   0.94322
#     5      0.183975   0.152994   0.943739
#     6      0.179724   0.150535   0.944951
#     7      0.177739   0.149299   0.945759
#     8      0.175992   0.147078   0.946105
#     9      0.176934   0.145998   0.946682
# [array([ 0.146]), 0.9466820542343215]

# %%
learn.fit(1e-2, 5, cycle_len=1)

# %%
learn.fit(1e-2, 10, cycle_len=1)

# %% [markdown]
# ### unfreeze + discriminative lrs

# %%
learn.unfreeze()
lr = 1e-3
lrs = [lr/100, lr/10, lr]
learn.fit(lrs, 10, cycle_len=1)

# %% [markdown]
# ### test model

# %%
learn.load("resnet18_224")
